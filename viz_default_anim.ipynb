# %%
# %matplotlib widget

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import IPython
import numpy as np
from matplotlib import pyplot as plt

import datasets

meta, data = np.load('anims/ds_bottle1_body1_left_1500.npy', allow_pickle=True)

data = datasets.deg2rad(data)

# %%
def gen_fig(d):
    _fig, ax = plt.subplots(2)
    i = 0
    d = d#[:, i:i+3]
    # ax[].hist(d)
    # print(d.shape)
    ax[0].imshow(tf.transpose(d)) 
    d, c = datasets.recluster(d)
    # ax[0].hist(tf.transpose(d[:, 0]))
    # ax[1].hist(tf.transpose(d[:, 1]))
    # ax[2].hist(tf.transpose(d[:, 2]))
    ax[1].imshow(tf.transpose(d)) 
    plt.show()

gen_fig(data)
# Out:
# angles shape: (500, 23)
# circular_means shape: (23,)
# circular_means: tf.Tensor(
# [ 1.33418792 -0.56504442  0.25679974  1.3229059   0.45807797 -0.67545908
#  -0.31381114  3.03461446 -2.99857568  0.01462387 -0.55457969 -3.11198322
#  -2.9503995  -0.23496519 -0.22170049 -3.01266261 -2.94509526 -0.05096775
#  -0.16831166 -3.08499867 -2.7993078   0.37703766 -0.10648236], shape=(23,), dtype=float64)
# angles: [[ 1.89096825 -1.25760537 -0.22429034 ... -2.94702858  0.61568688
#   -0.28023705]
#  [ 1.89148487 -1.25754725 -0.22476385 ... -2.94726246  0.61422762
#   -0.2799276 ]
#  [ 1.89082688 -1.25723152 -0.2238493  ... -2.94711585  0.61365078
#   -0.28067582]
#  ...
#  [ 1.43745492 -0.50902388  0.23205147 ... -2.68803918  0.24969186
#   -0.35485511]
#  [ 1.43907004 -0.51378723  0.22773632 ... -2.68284857  0.20972417
#   -0.35368172]
#  [ 1.44324749 -0.50144758  0.22597075 ... -2.64645322  0.11051275
#   -0.3376308 ]]
# angles adjusted (before wrap): tf.Tensor(
# ...

# %%
np.sin([3.12015652, -3.13572835])
# Out:
# array([ 0.02143449, -0.00586427])
